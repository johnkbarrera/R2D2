# %%
import os
import pandas as pd
import numpy as np
import math
from datetime import datetime

# %% [markdown]
# ### Recuperando datos

# %%
# Reclamos
file_name = 'data/fuente_to_process.csv'
datos_reclamos = pd.read_pickle(file_name)

# Catalogos BN

catalogo_sbs = pd.read_csv('catalogo/catalogo_sbs_motivo.csv')
catalogo_sbs.head()
# Out:
#       N° Reclamo                        Nombre N° Docum.  Cod. Servicio  \
# N°
# 1    002718-7736            ADAN HOLGUIN SOLIS  42672067           2200
# 2      067618-34  ADANAQUE TIZON MARIA LILIANA  45056104           2200
# 3    002718-7726         ADEMIR CHAVEZ SANCHEZ  41311452           2200
# 4   315118-10281    AGUERO OLIVAS JOHN RICHARD  40383052           2200
# 5       034618-9    AGUILAR VEGA JULIO EDUARDO  45451586           2200
#
#                Servicio  Cod Motivo                                   Motivo  \
# N°
# 1   CAJEROS AUTOMATICOS    280800.0  PRCA - NO DISPENSÓ EFECTIVO Y/O VOUCHER
# 2   CAJEROS AUTOMATICOS    280800.0  PRCA - NO DISPENSÓ EFECTIVO Y/O VOUCHER
# 3   CAJEROS AUTOMATICOS    280800.0  PRCA - NO DISPENSÓ EFECTIVO Y/O VOUCHER
# 4   CAJEROS AUTOMATICOS    280800.0  PRCA - NO DISPENSÓ EFECTIVO Y/O VOUCHER
# 5   CAJEROS AUTOMATICOS    280800.0  PRCA - NO DISPENSÓ EFECTIVO Y/O VOUCHER
#
# ...

# %%
catalogo_sbs = pd.read_csv('catalogo/catalogo_sbs_motivo.csv')
catalogo_sbs.head()
# Out:
#             Tipo Nivel  Cod SBS  \
# 0    Informativo   1er       21
# 1  Transaccional   1er       28
# 2  Transaccional   1er       28
# 3    Informativo   1er      107
# 4    Informativo   1er      108
#
#                                           Motivo SBS Categoria
# 0  Publicidad engañosa o información que induce a...    Motivo
# 1            Prca - No dispensó efectivo y/o voucher    Motivo
# 2                        Prca - Retención de tarjeta    Motivo
# 3  Modificaciones contractuales del crédito – Ins...    Motivo
# 4  Modificaciones contractuales del crédito – Ins...    Motivo
