# %%
import os
import pandas as pd
import numpy as np
import math
from datetime import datetime

# %% [markdown]
# ### Recuperando datos

# %%
# Reclamos
file_name = 'data/fuente_to_process.csv'
datos_reclamos = pd.read_pickle(file_name)

# Catalogos BN
catalogo_bn_motivo = pd.read_csv('catalogo/catalogo_motivos.csv')
catalogo_bn_servicio = pd.read_csv('catalogo/catalogo_servicios.csv')

# Catalogos SBS
catalogo_sbs_motivo = pd.read_csv('catalogo/catalogo_sbs_motivo.csv')
catalogo_sbs_servicio = pd.read_csv('catalogo/catalogo_sbs_motivo.csv')

# %%
datos_reclamos.columns
# Out:
# Index(['N° Reclamo', 'Nombre', 'N° Docum.', 'Cod. Servicio', 'Servicio',
#        'Cod Motivo', 'Motivo', 'Cod. Atm', 'Det. AtmError', 'N° Cajero',
#        'Monto', 'Operac.', 'Present.', 'Resul.', 'Recl.', 'Cod. Oficina',
#        'Det. Oficina', 'Regional', 'Dependencia', 'Cod. Deriv',
#        'Última Derivació', 'N° Memo Carta Resp.', 'Dirección Domic.',
#        'Fase del Reclamo', 'Proceso', 'Días de Demora', ' de Demora', 'Respon',
#        'Responsable', 'Macroregión', 'Resp.', 'División',
#        'División Responsable', 'Cod. Dept', 'Responsable.1',
#        'Mes Presentacion', 'Días Reclamo', 'Año Presentación', 'Semáforo',
#        'Situación', 'Cod. Usuario', 'Nombre Usuario', 'Descripción Fase',
#        'Canal Ingreso', 'Medio Respuesta', 'Reclamo/requerim', 'Hace carta',
#        'Correo', 'Cta. Ahorro', 'Descripcion', 'Motivo.1', 'DEPARTAMEN',
#        'PROVINCIA', 'DISTRITO', 'IS_LIMA', 'fecha_fase1', 'fecha_fase2',
#        'fecha_fase3', 'fecha_fase4', 'fecha_fase5', 'fecha_fase6',
#        'fecha_fase7'],
#       dtype='object')

# %%
catalogo_bn_servicio.columns
# Out:
# Index(['Cod Servicio', 'Cod Servicio SBS', 'Servicio Corregido', 'Servicio',
#        'Cantidad'],
#       dtype='object')

# %%
catalogo_bn_servicio.head()
# Out:
#    Cod Servicio  Cod Servicio SBS  \
# 0          2200               102
# 1           600                 6
# 2           304                29
# 3           400               102
# 4          9600                96
#
#                                   Servicio Corregido  \
# 0  CUENTA DE AHORRO (DESTINADA A DEPÓSITO DE REMU...
# 1                           TARJETA DE DEBITO - VISA
# 2                                SERVICIOS VARIOS
# 3  CUENTA DE AHORRO (DESTINADA A DEPÓSITO DE REMU...
# 4                    SERVICIO DE ATENCION AL USUARIO
#
#                           Servicio  Cantidad
# 0              CAJEROS AUTOMATICOS     20796
# 1         TARJETA DE DEBITO - VISA     12138
# 2          BONO FAMILIAR UNIVERSAL      7413
# 3                      BANCA MOVIL      4181
# 4  SERVICIO DE ATENCION AL USUARIO      3174

# %%
# Merge Motivos
datos_reclamos_merged = pd.merge(
                            datos_reclamos,
                            catalogo_bn_motivo[['Cod Motivo', 'Cod Motivo SBS', 'Motivo Corregido']],
                            how="inner",
                            left_on='Cod Motivo',
                            right_on='Cod Motivo',
                            sort=True,
                            suffixes=("_x", "_y"),
                        )
# Merge servicios
datos_reclamos_merged = pd.merge(
                            datos_reclamos_merged,
                            catalogo_bn_servicio[['Cod Servicio', 'Cod Servicio SBS', 'Servicio Corregido']],
                            how="inner",
                            left_on='Cod. Servicio',
                            right_on='Cod Servicio',
                            sort=True,
                            suffixes=("_x", "_y"),
                        )

# %%
len(datos_reclamos)
# Out:
# 248058

# %%
datos_reclamos_merged.head()
# Out:
#     N° Reclamo                        Nombre N° Docum.  Cod. Servicio  \
# 0     023818-7  TORRES SENMACHE PATHY PAMELA  41114765            100
# 1  002718-4016         CARLOS RIQUELME ROMAN  43471167            100
# 2  002719-6276   RICARDO ARTURO RIVERA NUÑEZ  30831857            100
# 3   010119-356       VERAMENDI ANCASI JAVIER  09952556            100
# 4   010119-354        MEDINA RAMOS JOSE LUIS  29353518            100
#
#            Servicio  Cod Motivo  \
# 0  CUENTA DE AHORRO     10000.0
# 1  CUENTA DE AHORRO     10000.0
# 2  CUENTA DE AHORRO     10000.0
# 3  CUENTA DE AHORRO     10000.0
# 4  CUENTA DE AHORRO     10000.0
#
#                                               Motivo  Cod. Atm Det. AtmError  \
# 0  ICCC - INCUMPLIMIENTO DE CLAUSULAS DEL CONTRAT...       NaN           NaN
# 1  ICCC - INCUMPLIMIENTO DE CLAUSULAS DEL CONTRAT...       NaN           NaN
# 2  ICCC - INCUMPLIMIENTO DE CLAUSULAS DEL CONTRAT...       NaN           NaN
# 3  ICCC - INCUMPLIMIENTO DE CLAUSULAS DEL CONTRAT...       NaN           NaN
# 4  ICCC - INCUMPLIMIENTO DE CLAUSULAS DEL CONTRAT...       NaN           NaN
#
#    N° Cajero  ... fecha_fase3 fecha_fase4 fecha_fase5 fecha_fase6 fecha_fase7  \
# 0        NaN  ...  2018-10-03  2018-10-03  2018-10-03  2018-10-03  2018-10-03
# 1        NaN  ...  2018-09-24  2018-09-26  2018-09-26  2018-09-26  2018-09-26
# 2        NaN  ...  2020-02-07  2020-02-10  2020-02-10  2020-02-10  2020-02-11
# 3        NaN  ...  2019-12-18  2019-12-19  2019-12-20  2019-12-20  2019-12-20
# 4        NaN  ...  2019-11-07  2019-11-11  2019-11-12  2019-11-12  2019-11-12
#
#    Cod Motivo SBS                                   Motivo Corregido  \
# 0               1  INCUMPLIMIENTO DE CLAUSULAS DE LOS CONTRATOS, ...
# 1               1  INCUMPLIMIENTO DE CLAUSULAS DE LOS CONTRATOS, ...
# 2               1  INCUMPLIMIENTO DE CLAUSULAS DE LOS CONTRATOS, ...
# 3               1  INCUMPLIMIENTO DE CLAUSULAS DE LOS CONTRATOS, ...
# 4               1  INCUMPLIMIENTO DE CLAUSULAS DE LOS CONTRATOS, ...
#
#   Cod Servicio Cod Servicio SBS  \
# 0          100              102
# 1          100              102
# 2          100              102
# 3          100              102
# 4          100              102
#
#                                   Servicio Corregido
# 0  CUENTA DE AHORRO (DESTINADA A DEPÓSITO DE REMU...
# 1  CUENTA DE AHORRO (DESTINADA A DEPÓSITO DE REMU...
# 2  CUENTA DE AHORRO (DESTINADA A DEPÓSITO DE REMU...
# 3  CUENTA DE AHORRO (DESTINADA A DEPÓSITO DE REMU...
# 4  CUENTA DE AHORRO (DESTINADA A DEPÓSITO DE REMU...
#
# [5 rows x 67 columns]
