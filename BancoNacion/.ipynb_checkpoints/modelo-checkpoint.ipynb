# %%
import pandas as pd

# %%
catalogo_bn = pd.read_csv('catalogo/catalogo_motivos.csv')
catalogo_bn.head()
# Out:
#    Cod Motivo  Cod SBS                                   Motivo Corregido  \
# 0      280800       28            PRCA - NO DISPENSÓ EFECTIVO Y/O VOUCHER
# 1       60100        6           TRANSACCION NO PROCESADA / MAL REALIZADA
# 2       30000        3  COBRO INDEBIDO DE INTERESES,COMISIONES,PORTES,...
# 3      180000       18  OPERACIONES EN CUENTA NO RECONOCIDAS (CONSUMOS...
# 4      300000       30  FALLAS DEL SISTEMA INFORMATICO QUE DIFICULTAN ...
#
#                                               Motivo  Cantidad
# 0            PRCA - NO DISPENSÓ EFECTIVO Y/O VOUCHER     16911
# 1           TRANSACCION NO PROCESADA / MAL REALIZADA     11538
# 2  CIIC- COBRO INDEBIDO DE INTERESES,COMISIONES,P...      5828
# 3  OCNR - OPERACIONES EN CUENTA NO RECONOCIDAS (C...      5682
# 4  FALLAS DEL SISTEMA INFORMATICO QUE DIFICULTAN ...      2539

# %%
catalogo_sbs = pd.read_csv('catalogo/catalogo_sbs_motivo.csv')
catalogo_sbs.head()
# Out:
#             Tipo Nivel  Cod SBS  \
# 0    Informativo   1er       21
# 1  Transaccional   1er       28
# 2  Transaccional   1er       28
# 3    Informativo   1er      107
# 4    Informativo   1er      108
#
#                                           Motivo SBS Categoria
# 0  Publicidad engañosa o información que induce a...    Motivo
# 1            Prca - No dispensó efectivo y/o voucher    Motivo
# 2                        Prca - Retención de tarjeta    Motivo
# 3  Modificaciones contractuales del crédito – Ins...    Motivo
# 4  Modificaciones contractuales del crédito – Ins...    Motivo
