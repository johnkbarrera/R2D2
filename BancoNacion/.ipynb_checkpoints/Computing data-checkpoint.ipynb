# %%
# !pip install -U gensim
# !pip install -U spacy
# !pip install nltk
# !pip install pyLDAvis
# #!conda install pyplot

# !python -m spacy download es_core_news_sm
# !python -m spacy link es_core_news_sm es

# %%
#!conda install -c plotly plotly=5.6.0

# %%
import os
import pandas as pd
import numpy as np
import math
from datetime import datetime
from tqdm import tqdm, trange

import matplotlib.pyplot as plt
import plotly.express as px
from difflib import SequenceMatcher

# %%
# Reclamos
file_name = 'data/data_merged.csv'
data_to_process = pd.read_pickle(file_name)

# %%
# Filtramos solo nivel 1
data_to_process = data_to_process[data_to_process['Nivel']=='1er'].reset_index(drop=True)

# %%
dicionarios_reglas = {}
dicionarios_reglas['ATENCION_USUARIO'] = {}
dicionarios_reglas['ATENCION_USUARIO']['servicios'] =['96']
dicionarios_reglas['ATENCION_USUARIO']['motivos'] =['39']
dicionarios_reglas['ATENCION_USUARIO']['canal'] =[]

# %%
dicionarios_reglas
# Out:
# {'ATENCION_USUARIO': {'servicios': ['96'], 'motivos': ['39'], 'canal': []}}

# %%
# Filtramos servicion de interes

# ATENCION AL USUARIO

# %%
data_temp = data_to_process[(data_to_process['Servicio SBS']=='96')&(data_to_process['fecha fase 1'].dt.year>=2019)]
data_temp.head()
# Out:
#        Numero reclamo                           Nombre Numero documento  \
# 160305   002720-47012         MAXIMILIANA EUGENIO JARA         01017113
# 160306   002720-42872            GABRIELA PALIZA ROZAS         47993150
# 160307   002720-28312  ROSA MARGARITA BARDALES HERRERA         08291615
# 160308   002720-28315   YRVIN JAIME VILLANUEVA CORDOVA         17807119
# 160309   002720-25710       GUADALUPE JARAMILLO GARCIA         76027341
#
#        Cod servicio Cod motivo  Cod ATM                ATM error  \
# 160305         9600     150000     99.0  (cajero multired) OTROS
# 160306         9600     150000      NaN                      NaN
# 160307         9600     150000      NaN                      NaN
# 160308         9600     150000      NaN                      NaN
# 160309         9600     150000      NaN                      NaN
#
#         Numero cajero Monto Fecha operacion  ... fecha fase 7 Servicio BN  \
# 160305            NaN   NaN      06/10/2020  ...   2021-02-16        9600
# 160306            NaN   NaN      21/09/2020  ...   2020-09-25        9600
# 160307            NaN   NaN      21/07/2020  ...   2021-01-01        9600
# 160308            NaN  1000      08/07/2020  ...   2020-11-04        9600
# 160309            NaN   NaN      03/07/2020  ...   2020-08-21        9600
#
#        Motivo BN  Canal Incidencia SBS Servicio SBS Motivo SBS  \
# 160305    150000                    01           96         15
# 160306    150000                    01           96         15
# 160307    150000                    01           96         15
# 160308    150000                    01           96         15
# 160309    150000                    01           96         15
#
#        Canal Incidencia                         Servicio  \
# 160305          OFICINA  SERVICIO DE ATENCION AL USUARIO
# 160306          OFICINA  SERVICIO DE ATENCION AL USUARIO
# 160307          OFICINA  SERVICIO DE ATENCION AL USUARIO
# 160308          OFICINA  SERVICIO DE ATENCION AL USUARIO
# 160309          OFICINA  SERVICIO DE ATENCION AL USUARIO
#
#                                                    Motivo Nivel
# 160305  PROBLEM. CON TARJETA DEBITO / CREDITO (RETENID...   1er
# 160306  PROBLEM. CON TARJETA DEBITO / CREDITO (RETENID...   1er
# 160307  PROBLEM. CON TARJETA DEBITO / CREDITO (RETENID...   1er
# 160308  PROBLEM. CON TARJETA DEBITO / CREDITO (RETENID...   1er
# 160309  PROBLEM. CON TARJETA DEBITO / CREDITO (RETENID...   1er
#
# [5 rows x 55 columns]

# %%
data_temp = data_to_process[(data_to_process['Servicio SBS']=='96')&(data_to_process['Motivo SBS']=='39')]

data_prof = data_to_process[~(data_to_process['Servicio SBS']=='96')]
data_temp.head()
# Out:
#        Numero reclamo                          Nombre Numero documento  \
# 166548     001318-277  AVALOS CHUMPITAZ AMELIA TERESA         08814304
# 166549     005118-266  CIEZA RODRIGUEZ ESTHER CELINDA         41211946
# 166550     002518-409   ESPINOZA BERROCAL JAIME EDIEE         08064474
# 166551    002718-7738        HASSAN QUIÑONES VILLASIS         16733568
# 166552     006118-170             VARGAS PEZUA ALICIA         41183944
#
#        Cod servicio Cod motivo  Cod ATM ATM error  Numero cajero Monto  \
# 166548         9600     390000      NaN       NaN            NaN   NaN
# 166549         9600     390000      NaN       NaN            NaN   NaN
# 166550         9600     390000      NaN       NaN            NaN   NaN
# 166551         9600     390000      NaN       NaN            NaN   NaN
# 166552         9600     390000      NaN       NaN            NaN   NaN
#
#        Fecha operacion  ... fecha fase 7 Servicio BN Motivo BN  \
# 166548      31/12/2018  ...   2019-01-31        9600    390000
# 166549      31/12/2018  ...   2019-02-08        9600    390000
# 166550      29/12/2018  ...   2019-01-31        9600    390000
# 166551      31/12/2018  ...   2019-01-25        9600    390000
# 166552      31/12/2018  ...   2019-02-05        9600    390000
#
#         Canal Incidencia SBS Servicio SBS Motivo SBS Canal Incidencia  \
# 166548                    01           96         39          OFICINA
# 166549                    01           96         39          OFICINA
# 166550                    01           96         39          OFICINA
# 166551                    01           96         39          OFICINA
# 166552                    01           96         39          OFICINA
#
#                                Servicio                          Motivo Nivel
# 166548  SERVICIO DE ATENCION AL USUARIO  INADECUADA ATENCION AL USUARIO   1er
# 166549  SERVICIO DE ATENCION AL USUARIO  INADECUADA ATENCION AL USUARIO   1er
# 166550  SERVICIO DE ATENCION AL USUARIO  INADECUADA ATENCION AL USUARIO   1er
# 166551  SERVICIO DE ATENCION AL USUARIO  INADECUADA ATENCION AL USUARIO   1er
# 166552  SERVICIO DE ATENCION AL USUARIO  INADECUADA ATENCION AL USUARIO   1er
#
# [5 rows x 55 columns]

# %%
data_to_process['Servicio BN'].unique()
# Out:
# array(['100', '1100', '1200', '1700', '1800', '200', '2200', '2300',
#        '2700', '2701', '2801', '2901', '2902', '3000', '301', '302',
#        '303', '304', '400', '700', '800', '900', '9600', '9902', '9904',
#        '9905'], dtype=object)

# %%
# data_temp['Descripcion']

# %%
# Descripcion de hechos ()
100, 101
# Out:
# (100, 101)

# %%
data_temp['Descripcion'].values[20]
# Out:
# 'SEGUN LIBRO DE RECLAMACIONES DERESPALDO N°83610 CLIENTE INDICA:\r\nLA CAJERA MARIZA SOLEDAD SPIRITU CHAFLOQUE ME ARRANCHÓ LA SOLICITUD DE TARJETA; LUEGO TIRÓ DE MALA MANERA LA SOLICITUD DE TOKEN Y SIN CULMINAR  LA ATENCIÓN ME DIJO QUE SE IBA A REFRIGERIO SÓLO PORQUE LE RECLAMÉ SU PÉSIMA ATENCIÓN,LUEGO DE HACER MI COLA PARA EL RECLAMO LA CAJERA CONTINUA ATENDIENDO. Y ME REALIZÓ UN COBRO INDEBIDO DE S/12.00\r\nPÉSIMO SERVICIO.'

# %% [markdown]
# # Modelo LDA

# %%
import re

from difflib import SequenceMatcher

import nltk
nltk.download('stopwords')
#from nltk.book import *
from nltk.probability import FreqDist
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\johnk\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Texto a  minusculas
data_temp['texto']= data_temp['Descripcion'].str.lower()

# nan to  ''
print('Elementos nulos', len(data_temp[data_temp['texto'].isna()]))
data_temp['texto'] = data_temp['texto'].fillna('')
print('Elementos nulos', len(data_temp[data_temp['texto'].isna()]))
# Out:
# Elementos nulos 0
# Elementos nulos 0
# C:\Users\johnk\AppData\Local\Temp/ipykernel_22036/298238503.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_temp['texto']= data_temp['Descripcion'].str.lower()
# C:\Users\johnk\AppData\Local\Temp/ipykernel_22036/298238503.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_temp['texto'] = data_temp['texto'].fillna('')

# %% [markdown]
# ### Preparacion de palabras clave

# %%
import string
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

stop_words = stopwords.words('spanish')
stop_words.extend(["rt", "aun", "oe"])

exclude = string.punctuation
exclude = exclude + "¿"

lemma = SnowballStemmer('spanish')

# %%
# print(stop_words)

# %% [markdown]
# ### Eliminar URL y caracteres de nueva línea

# %%
def remove_three_dots(list_text):
    return [re.sub(r"[a-zA-Z]+(\……|\…)$", " ", texto) for texto in list_text]

def remove_three_dots(list_text):
    return [re.sub("[\.]"*3, " ", texto) for texto in list_text]

def remove_url(list_text):
    return [re.sub(r"http\S+", "", texto).strip() for texto in list_text]

def remove_breakline(list_text):
    return [re.sub('\s+', ' ', texto) for texto in list_text]

def remove_single_quotes(list_text):
    return [re.sub("\'", "", texto) for texto in list_text]

# %% [markdown]
# ### Validando funciones de procesamiento

# %%
txt = data_temp['texto'].values.tolist()
print(txt[20])
# Out:
# segun libro de reclamaciones derespaldo n°83610 cliente indica:
# la cajera mariza soledad spiritu chafloque me arranchó la solicitud de tarjeta; luego tiró de mala manera la solicitud de token y sin culminar  la atención me dijo que se iba a refrigerio sólo porque le reclamé su pésima atención,luego de hacer mi cola para el reclamo la cajera continua atendiendo. y me realizó un cobro indebido de s/12.00
# pésimo servicio.

# %% [markdown]
# ### Tokenizando palabra y limpieza de texto

# %%
# txt = [data_temp['texto'].values.tolist()[20]+'...']

# %%
import gensim

cleared_txt = remove_url(txt)
cleared_txt = remove_three_dots(cleared_txt)
cleared_txt = remove_breakline(cleared_txt)
cleared_txt = remove_single_quotes(cleared_txt)

# %%
cleared_txt
# Out:
# ['clienta manifiesta que el dia 31/12/2018 se acerco a solicitar su tarjeta multired por concepto judicial alimentista. recibio un mal trato por parte del personal de atencion al usuario, la atencion de la ventanilla 11 fue pesima indicandole que no la atenderia y que espere que le atienda el encargado de tarjetas. el personal que atiende en atencion al usuario debe estar capacitado para atender y orientar mejor al cliente y disponer de suficiente personal para la atencion.',
#  'cliente menciona que se acerco a la ventanilla 1 para realizar unos pagos, el gestor sin saludar le pgto " que va hacer", la cliente le mencionó que hará unos pagos de detracción y el gestor se nego a atender porque la ventanilla es caja rapida y la mando hacer otra cola, esto molesto al cliente ya que en esa ventanilla no tenia ningun letrero de caja rapida. cliente solicita una mejor atención de parte de los trabajadores ya que no es la primera vez que le sucede en esta agencia.',
#  'transcrito segun libro de reclamos "no quisieron atender por falta de sistema el estado de cuenta "',
#  'hoy dia 31.12.2018 aprox. 11.00 am me apersone a la agencia miraflores y efectue un deposito de ahorros por alimentos .al momento de tomarle una foto al voucher se acercó el vigilante machado la torre para decirme que no debo utilizar el celular en el banco. al momento de retirarme el vigilante me dijo de mala forma "avanza avanza y andate". me llamó la atención su trato y le dije que hablaría con el administrador y éste me contestó hable con quién quiera. yo acepto mi error y pido disculpas. sin embargo reclamo por el maltrato recibido de parte del vigilante de esta importante institución.',
#  'cliente indica que el banco de villa el svador no se da abasto para atender a todo el publico y que siempre tiene q hacer lasgas colas y esperar mas de 1:30 por una operacion. solicita halla otro banco en villa el savador. cliente indica que llego a las 11:40am y la tendieron.a las 2:10 pm. y no es la primera vez.',
#  'el día de hoy 31.12.2018 a las 14:30 aproximadamente la oficina del banco de la nación en puno dejó de atender a los usuarios sin razón aparente, perjudicandome así como a otros usuarios que estaban en cola de espera.',
#  'despues de haber hecho cola durante 1 hora, no me han atendido con el pago judicial ordenado por el juez del 35° juzgado de trabajo, por el monto de s/. 82,468.82. segun alega la jefa de operaciones, sra. malpartida, éste tiene que ser consultado por telefono con el poder judicial, procedimiento que a mi parecer es innecesario y burocratico, ya que he presentado la orden del juez y la resolucion judicial n° 35 (original) y esto lo puede corroborrar vía web www.pj.gob.pe el presente reclamo ha sido registrado ademas en el libro de reclamaciones de respaldo siendo las 17:22 horas del dia 28/12/2018',
#  'transcrito segun libro de reclamaciones "el administrador se nego a atenderme aduciendo que tenia que traer la escritura publica de un poder otorgado en milan, se presento certificado literal expedido por registros publicos en original".',
#  'el control de ingreso de personas al banco es desordenado y los encargados no controlan por lo que los que respetamos la fila nos perjudicamos.',
#  'usuario indica haber estado haciendo su cola y la ventanilla nro 13 coloca su letrero de ventanilla cerrada pero al mismo tiempo se encuentraba realizando operaciones por fuera de la cola de atencion. esto le causa indignacion al usuario ya que no se respeta la cola de atencion.',
#  'transcrito segun libro de reclamaciones "yo laurecilda benavides siempre soy cliente de este banco y siempre vengo con mi paciente en silla de ruedas pero no me permitieron hacer cola preferencial."',
#  'mala atencion y mala informacion de la ventanilla 08 (danitza larico) y 14 (srta alejandrina)y que no la querian atender hasta que fue a administracion y la atendio otra ventanilla y atencion discriminatoria.',
#  '“el presente reclamo ha sido registrado además en el libro de reclamaciones de respaldo nº122511" cliente manofiesta lo siguiente: que habiendo gran cantidad de gente el cajero no se abastece (atm) y los fines de semana casi no hay plata. por esa razon me gustaria que haya otro cajero (atm) mas por la afluencia de gente.',
#  'segun libro de reclamaciones derespaldo n°83610 cliente indica: la cajera mariza soledad spiritu chafloque me arranchó la solicitud de tarjeta; luego tiró de mala manera la solicitud de token y sin culminar la atención me dijo que se iba a refrigerio sólo porque le reclamé su pésima atención,luego de hacer mi cola para el reclamo la cajera continua atendiendo. y me realizó un cobro indebido de s/12.00 pésimo servicio.',
#  'el sr saul luego de mi atencion no me pudo dar ningun sustento tangible del procedimiento a seguir , me indico que en este banco de la nacion no se puede abrir una cuenta de ahorros cliente queria depositar sus monedas de 0.01 centimo < el presente reclamo ha sido registrado ademas en el libro de reclamaciones de respaldo >',
#  'el día 27/12/2018 me apersoné a las oficinas del banco de la nación en el distrito de san juan de marcona y evidencié que las sillas para la espera de los usuarios (la mayoría de ellos adultos mayores y niños) se encuentran rotas representando un peligro para nosotros los usuarios. además no cuentan con el libro de reclamaciones a disposición de los usuarios, sino que nos indican que se debe conversar con el administrador antes de acceder al libro.',
#  'cliente indica que el agente de seguridad da preferencia a clientes que no se encuentran en la cola de espera para atencion al publico. mejorar calidad de atencion al cliente.',
#  'he intentado comunicarme al numero de contacto del call center del banco de la nacion y sale numero ocupado. lo he realizado desde diferentes telefonos y en diferentes horarios. estoy demasiado molesta porque no ofrecen un buen servicio de atencion al cliente. es lamentable saber que no podria bloquear mi tarjeta en caso de robo o por una emergencia porque no tienen el servicio a disposicion del cliente',
#  'cliente manifiesta que se acerco a la ventanilla a solicitar el tramite de retiro de capial social. donde el cajero 2868 ever mendoza le indico que no le iba indicar el tiempo que demore la operacion que iba a realizar aun indicando el cliente que tenia premura con el tiempo para poder tomar una decision de realizar o no la operacion. considera el cliente que esa no es la forma de tratar a un cliente y solicita una amonestacion.',
#  'me han robado y desde hace hora y media no me atienden en los telefonos he intentadomuchas veces por todas sus lineas y no hay atencion, si hay uso de mi tarjeta reclamare en indecopi',
#  'extraido del libro de reclamaciones fisico. durante un mes soliicte el posible cambio de un billete de s7. 100.00 a2073519x partido pero completo de 03 de diciembre y el encargado de caja silva inventa muchas disculpas y no me da la soluciion, hoy debo ingresar a la otra semana en espera de respuesta de lima sin que me de documento o forma de foco del billete.',
#  'el sr. carlos espinoza al momento de atenderme me falto el respeto en cinco ocasiones con frases como: arranca de aqui; largate de aca;quieres algo mas gritando; largate a la 19;anda haz tu queja bastante te van a hacer caso; y haz lo que quieras; posteriormente me comunique con la sra. bernarda que me derivo a la ventanilla 19 donde me derivaron a conversar con el administrador el sr. trinidad, el cual me atendio y me regreso a la ventanilla 19 para que ingresen mi reclamo. solicito medidas correctivas con el susodicho o la disposicion de su cargo directamente.',
#  'cliente indica se apersono al área de plataforma de préstamo de la agencia juliaca donde atiende el sr carlos ponce a solicitar información sobre su refinanciamiento de préstamo multired, el sr carlos ponce tuvo un comportamiento inadecuado para con el cliente siendo déspota, malcriado y no quiso atender al señor en varias oportunidades siendo el cliente amable. en oportunidades pasadas el cliente se apersono al banco de la nación juliaca a solicitar información sobre su préstamo y fue atendido por el sr carlos ponce el cual luego de ped
#  'falta de respeto por parte del sr escobedo pasario ch. al solicitarle fila de 3era edad. yo con cancer y discapacidad. hoja de reclamacion de respaldo 77011.',
#  'reclamo respecto del sr milton calancha cuba por no haber dado una solución como ususario, diciendo que el reclamo iba a ser resuelto el sabado 29 de diciembre y que tenía hasta 30 dias para resolver el problema, trato con el ususario deja mucho que desear.',
#  'cliente manifiesta mala atencion al usuario por parte del señor cesar lozada que ante la consulta realizada les respondio groseramente no dando solucion a la consulta.',
#  'segun el banco la atencion telefónica son las 24 horas, la atención es pésima ya que intente el bloqueo de mi tarjeta por mas de dos horas y la verdad está atención de bloqueo debería ser rápida y eficaz, yo no se si habrán dado con la contraseña o no ya que la atención fue lenta y con mucho tiempo, con riesgo a robo. mejorar pesima atención.',
#  'el sr.luis cañamero se nego atenderme y me mando a otra ventanilla que me atiendan con amabilidad recibiendo maltrato sicologico por ser de tercera edad y la cola era larga y luego atendio a una srta joven, notando disciminacion a mi persona de tercera edad. ingresado en libro de respaldo fol. 78230',
#  'buenos dias. el dia 21 de diciembre. llegue 02:00 pm. haciendo fila pasando hambre, sed y cansancio. para que las 5:30 pm hora exacta que cierra el banco. nos cierren las puertas y no nos atindan junto a mas de 30 personas. es injusto. gracias.',
#  'el dia de hoy me acerque para realizar un retiro en el cajero de la agencia castilla siembargo las personasue estanban delante de la cola no podian retirar por lo que me acerque junto a otro cliente donde el vigilante sr javier arambulo palacion que se encontraba en la puerta a fin de que pudiera avisar a alguien de la agencia que el cajero tenia problemas contestandome de forma grocera es mas pude ser testigo del maltrato que le dio a un acompañante de una señora de la tercera edad al querer el mismo ir a verificar el cajero sin avisarle a nadie de la agencia. despues que el se acerco el sistema del cajero ya se habia regularizado y se acerco a nosotros gritando y haciendo señas que el cajero esta funcionando de forma normal, siendo esto una falta de respeto porque el esta para prestar seguridad y tratar de orientar al publico',
#  'ustedes como banco tienen un horario de atencion, y no es la primera vez que cierran antes de tiempo, quise presentar mi reclamo y no fueron capaces de hacer valer mi derecho, solo el señor de seguridad se comporto grosero con ganas de querer irse.y no fui la unica. osea yo poidiendo permiso d emi trabajo media hora antes para poder ingresar y qu eeste tipo solo diga ya cerramos siendo 5:25.',
#  'el reclamos es por que siempre se ha dado dos filas para atencion de pension 65 o programa juntos. que se esta en contra del trabajop del personal del banco de sihuas.',
#  'existe 5 ventanillas de atencion preferencial la cola es larga y todas son preferenciales de edad (embarazadas,con niños,ancianos) y solamente atienden 2 ventanillas. no hay persona que de información donde se puede realizar un reclamo.',
#  'el día de hoy 21 de diciembre a horas 3:00de la tarde aproximadamente ,mi hermano estaba en la cola para cobrar,así que yo ingrese al banco a esperarle de manera serena hasta q el ingrese ,pero el vigilante no me dejo ingresar diciendomelo de mala manera «que no puedo ingresar» pero había otros que si estaban esperando a que ingresen sus acompañantes ,anteriores veces q fui acompañando no me trataron así y no me impidieron el ingreso,es por ello mi reclamo q el trato q me dieron me a echo tener una mala imagen de sus servicios ,honestamente si me preguntan q banco me recomiendas yo diría cualquier otro q no sea este.',
es a preguntar por el administrador para ingresar un reclamo pero el administrador no se encontraba en ese momento por lo que le indicaron que tenia que hablar con el jefe de operaciones de apellido tejada el cual lo atendio de manera prepotente y le brindo una mala atencion y ademas le indico que el usuario del bn no se tendria que porque acercar a la agencia ya que pueden ser sus operaciones por otros canales por lo que este inconveniente causa un malestar e incomodidad al cliente. cliente solicita lo siguiente: 1)sancion para el jefe de operaciones. 2)verificar mediante videos si era correcto el numero de personal que estaba atendiendo. 3)verificar si es correcto que el cliente solo puede realizar transacciones por otros canales y ya no por la agencia como indico el jefe de operaciones.',
# ...
#  'la sra. landeras pretell de ramirez luz elena manifiesta que el cajero jimmy javier rodríguez pérez reiteradas veces a mis empleadas les dijo porque yo depositaba diariamente para mis hijos a rioja y piura que debería hacerlo mensual, además está preguntando el movimiento de mi negocio. el cambio de sencillo tuve que apersonarme al banco para hacer valer mis derechos porque no querían cambiarme sencillo. la atención no es buena.',
#  'el cliente manifiesta que se encontraba en la cola general, donde observa que estan atendiendo a una señora de edad en la ventanilla n°9 a la cual le piden que coloque su huella en reiteradas veces, no pudiendo colocar la huella , por lo que estaba demorando; de la cola le indica al trabajador que sino hay otro tipo de procedimiento para que le atienda a la señora ya que se estaba demorando mucho; a lo que el trabajador le responde en forma sobrepotente sabes que no te metas, a lo que solicite su nombre y me dijo ven para acá que te lo voy a dar.',
#  'encontrandome haciendo cola para enviar un giro acudi al llamado del recibidor-pagador de la ventanilla 14 sr. espinoza en lugar de atenderme se puso a sellar unos documetos que tenia no me quizo atender me dijo que espere. le espere un buen rato y tampoco me atendia. procedi a irme a otra ventanilla. para que me llama si no me va a atender ademas que no tiene buen trato y se puso prepotente y bien malcriado. creo que deberian cambiarlo de oficina por que siempre que venga lo voy a encontrar y la verdad que no quisiera verlo.',
#  'cliente indica que se acercó al bn ubicado en avenida mariscal castilla n° 618 y la administradora se presneta como jefa del bn, quien le ha dicho que no tiene personal, otros se han ido a almorzar y algunos están enfermos, cuando el cliente le preguntó por qué solo hay dos ventanillas disponibles, ya que hay 10 ventanillas en la agencia. asimismo, cliente indica que había cola. el cliente indica que alrededor de 50 min estuvo esperando en la cola para que llegue su turno.',
#  'es el colmo siendo el banco de la nación, se forma colas hasta cuadras xa hacer depósitos y pagos de la sunat, detracciones, otros. falta implementar mas ventanillas xa no estar parada horas es mi caso.',
#  'la clienta menciona: llegue a la agencia 12:50pm para cancelar un impuesto, he esperado una hora y 10 mim. para ser atendida el tiempo de espera es demaciado donde esta la calidad de servicio al cliente,me parece un abuso de que teniendo 14 ventanillas hayan dejado 4 ventanilla operativas, 02 para la cola preferencial , 2 atencion a todos cuando en promedio eramos unas 80 personas. tener un poco de sentido comun y enviar a refrigerio por partes,la atencion que todos merecemos es demaciada escasa en sta oficina.',
#  'falta de seguridad en el cajero multired de la pampilladel hospital honorio delgado y privacidad. en el cajero multired de la pampilla la q está afuera del hospital honorio delgado, se evidencia ambulantes q se encuentran dentro del cajero y no hay privacidad para realizar retiro de dinero y no hay efectivos policiales alrededor , la cabina del multired, está llena de personas, dentro del lugar estan comiendo, hay coche de bebes, y por ello es q pasa los robos y cambio de tarjetas por personas extrañas, así como me pasó el 16.08.2018 + ó - 7:00 pm se me caercó un señor y sacó mi tarjeta del cajero',
#  'cliente manifiesta que su sr. padre armando castro rivera se acercó el día 07/08/2018 a la agencia de tumán -chiclayo a realizar un retiro al cajero automático de dicha agencia , y una de las señoras de limpieza de la agencia de tumán se le acercó y le dijo que lo ayudaría a retirar del cajero su dinero pero para eso le cobró al sr.armando s/5.00 por ayudarlo. indica que siempre la sra. de limpieza cobra a los jubilados por ayudarlos a retirar del cajero automatico de al agencia de tumán',
#  '..----------------------------------------------------------------------cliente manifiesta la mala atencion de la ventanilla 15 sr. carlos rossini ya que en presencia del publico coloca ventanilla cerrada y procede a llamar a una persona ajena al turno correspondiente. a razon de dicho acto el público reclama desatándose un insulto verbal de parte del empleado y de la persona o amigo al que llamo para atender el cual fue grosero con el publico con palabra de alto calibre.@@@@@@@##ñ por ambas partes asi mismo me llamo imbecil y que rebice el diccionario que no sabia donde estaba parado y que me vaya a reclamar a la administracion de una manera provocativa y asi sucesivamente los insultos.solicito las sanciones pertinentes ya que un funcionario o empleado publico no puede agredir verbalmente.',
#  'cliente manifiiesta que se acercó a la agencia trujillo ubicada en avenida diego de almagro n° 297 distrito y propv trujillo dpto la libertad. se encuentra en la agencia desde las 2.40 p.m para solicitar un cheque de gerencia, sin embargo le idnicaron que la atención inciaba a las 3.00 p.m. siendo las 3.29 p.m aun no se acerca nadie a la ventanilla para que el cliente pueda ser atendido.',
#  'en primer lugar, no es posible que en su página web indiquen que la agencia del módulo de justicia de paucarpata en arequipa atiende hasta las 5.30pm, siendo esto falso. segundo, voy a la agencia de miraflores (arequipa) antes del cierre de agencia, habiendo una cola en espera de poco más de 40 personas y al final (al momento de cierre) sólo hacen entrar a cerca de 15 personas y al resto nos botan. nunca me ha pasado esto en ninguna otra entidad.',
#  'hija del titular de la cuenta manifiesta inconformidad por parte de la trabajadora del area de mesa de ayuda del bn raisa gutierrez por el motivo que realizo una llamada telefónica al promediar las 8:35 am del dia 17/08/2018 por una consulta de un deposito en cuenta. manifiesta que la srita en mencion no resolvio la duda que tenia el titular de la cuenta y dio un trato inadecuado al cliente. por lo cual el cliente solicita que el personal tenga una capacitacion para mejorar el trato al usuario o que la cambien de área.',
#  'cliente manifiesta la mala atencion de la ventanilla 15 sr. carlos rossini ya que en presencia del publico coloca ventanilla cerrada y procede a llamar a una persona ajena al turno correspondiente. a razon de dicho acto el publico reclama desatandose un insulto verbal de parte del empleado y de la persona o amigo al que llamo para atender el cual fue grosero con el publico con palabra de alto calibre por ambas partes. mi posicion fue calmar y el me agredio de igual forma haciendo caso omiso a mis consejos,por lo que solicito las sanciones pertinentes y que sea evaluado psicologicamente.',
#  'cliente indica que se acercó a la oficina especial 1 prico remoto tarma en jirón arequipa n° 257 centro cívico int. c1 para realziar un depósito, pero la srta. de ventanilla le indicó que no está autorizada y que es la última vez que lo va a atender, además estaba preocupada por salir a tomar su desayuno e invító al cliente ingresar al interior de su ambiente para verfificar en la pantalla del computador que no está autorizada, lo cual el cliente manifiesta que le llamó la atención porque él no puede ingresar al interior del ambiente del banco.',
#  'estoy solicitando antecedentes penales, me dijeron que me los entregaban en una hora, retorne a la hora y me dijeron que aún no estaban y que era un problema de sistemas, le consulte si a la 1:45 podía retornar para recogerlos y me indicación que si, normal había atención, retorno 1:50 y no había nadie y se supone que si no atienden horario corrido deben informar al usuario porque no todos disponemos de horarios flexibles para poder ir a recoger ya que es personal. pésima atención, pésimo trato',
#  'deficiente atencion son las 11:00 am y 5 ventanillas no atienden hace 20 años es igual almuerzan almuerzan desde el desayuno. solo atienden 2 ventanillas.',
#  ...]

# %%
def texto_a_palabras(texto:str):
    for sentencia in texto:
        yield(gensim.utils.simple_preprocess(str(sentencia), deacc=True))

def texto_a_palabras2(texto:str):
    for sentencia in texto:
        yield(str(sentencia).split(" "))
        
data_palabras = list(texto_a_palabras2(cleared_txt))

# %% [markdown]
# ### N gramas

# %%
bigram = gensim.models.Phrases(data_palabras, min_count=5, threshold=100)
trigram = gensim.models.Phrases(bigram[data_palabras], threshold=100)

bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %% [markdown]
# ### Eliminar stoprwords, bigramas y lematizando texto

# %%
import spacy
spacy.prefer_gpu()

def remove_stopwords(texts):
    return [[word for word in gensim.utils.simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
data_words_nostops = remove_stopwords(data_palabras)
data_words_bigrams = make_bigrams(data_words_nostops)

# %%
#nlp = spacy.load('es', disable=['parser', 'ner'])
nlp = spacy.load('es_core_news_sm', disable=['parser', 'ner'])
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# %%
data_lemmatized[20]
# Out:
# ['segun',
#  'libro',
#  'reclamación',
#  'derespaldo ',
#  'cliente',
#  'indicar',
#  'marizar',
#  'soledad',
#  'chafloque',
#  'arranchar',
#  'solicitud',
#  'tarjeta',
#  'luego',
#  'tirar',
#  'malo',
#  'manera',
#  'solicitud',
#  'token',
#  'culminar',
#  'atención',
#  'decir',
#  'ir',
#  'refrigerio',
#  'sólo',
#  'reclamé',
#  'pésimo',
#  'atención',
#  'luego',
#  'hacer',
#  'reclamo',
#  'cajero',
#  'continuo',
#  'atender',
#  'realizar',
#  'cobro_indebido',
#  'pésimo',
#  'servicio']

# %%
# print(data_words_bigrams[0])

# %%
# print(data_lemmatized[100])

# %% [markdown]
# ### Creacion de diccionario y corpus
# El modelo LDA requiere dos entradas principales: corpus y diccionario

# %%
from gensim import corpora
 
# Diccionario
diccionario = corpora.Dictionary(data_lemmatized)

# Corpus
texto = data_lemmatized
corpus = [diccionario.doc2bow(doc) for doc in texto]

# %%
# print(data_words_bigrams[20])
# print(corpus[20])

# %% [markdown]
# ### Modelo LDA

# %%
# Correr y entrenar el modelo LDA sobre la matriz de términos.
lda_model = gensim.models.LdaModel(corpus,
                                   num_topics=4,
                                   id2word = diccionario,
                                   random_state=100,
                                   passes=10,
                                   update_every=1,
                                   chunksize=100,
                                   alpha='auto',
                                   per_word_topics=True)

# %% [markdown]
# ### Lista de temas del modelo LDA

# %%
for idx, topic in lda_model.print_topics():
    print('Topic: {} Word: {}\n'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.044*"hacer" + 0.031*"persona" + 0.019*"atender" + 0.018*"personal" + 0.017*"esperar" + 0.016*"banco" + 0.016*"atención" + 0.015*"solo" + 0.015*"hora" + 0.014*"cola"
#
# Topic: 1 Word: 0.034*"decir" + 0.027*"cliente" + 0.021*"indicar" + 0.016*"querer" + 0.013*"dar" + 0.012*"ventanillo" + 0.012*"señor" + 0.012*"realizar" + 0.010*"solicitar" + 0.009*"manera"
#
# Topic: 2 Word: 0.033*"pago" + 0.029*"tarjeta" + 0.025*"realizar" + 0.024*"contar" + 0.022*"sol" + 0.021*"dinero" + 0.015*"cajero" + 0.013*"pagar" + 0.013*"bono" + 0.012*"retiro"
#
# Topic: 3 Word: 0.023*"fecha" + 0.015*"día" + 0.014*"respuesta" + 0.013*"mes" + 0.013*"documento" + 0.012*"solicitar" + 0.010*"solicitud" + 0.009*"dicho" + 0.008*"pensión" + 0.008*"nación"

# %% [markdown]
# ### Visualizacion de topicos LDA

# %%
#import warnings
#import pyLDAvis.gensim
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

#warnings.filterwarnings('ignore')

pyLDAvis.enable_notebook()
vis = gensimvis.prepare(lda_model,corpus,diccionario)
vis
# Out:
# C:\Users\johnk\anaconda3\lib\site-packages\pyLDAvis\_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.166802 -0.099566       1        1  35.336289
# 0     -0.211707  0.168057       2        1  32.550384
# 2      0.118449 -0.259745       3        1  21.053179
# 3      0.260060  0.191254       4        1  11.060148, topic_info=          Term         Freq        Total Category  logprob  loglift
# 67       decir  4206.000000  4206.000000  Default  30.0000  30.0000
# 167    persona  3567.000000  3567.000000  Default  29.0000  29.0000
# 42        pago  2429.000000  2429.000000  Default  28.0000  28.0000
# 6      cliente  3350.000000  3350.000000  Default  27.0000  27.0000
# 25     tarjeta  2196.000000  2196.000000  Default  26.0000  26.0000
# ..         ...          ...          ...      ...      ...      ...
# 23   solicitar   457.685498  2285.826931   Topic4  -4.4484   0.5935
# 576      dicho   367.628229  1602.256029   Topic4  -4.6675   0.7297
# 138   presente   214.957021   469.115814   Topic4  -5.2041   1.4214
# 49      contar   223.294842  1990.336373   Topic4  -5.1661   0.0143
# 64       banco   213.822048  2126.366778   Topic4  -5.2094  -0.0952
#
# [211 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 5584      4  0.997091       abril
# 57        1  0.999188     acercar
# 29        1  0.998756      acerco
# 626       1  0.997237     actitud
# 2665      4  0.995832     adjunto
# ...     ...       ...         ...
# 48        2  0.432081  ventanilla
# 28        1  0.999518  ventanillo
# 353       1  0.888802         ver
# 353       2  0.110634         ver
# 94        2  0.998805   vigilante
#
# [236 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 1, 3, 4])

# %%
# lda_model.

# %%
#                             A B C D
# ATENCION AL USUARIO  [0]    3 4 2 1  = M1 = 4 =
# NO ATENCION AL USUARIO      1 2 1 1  = M2 = 2

# %%
# tfidf = gensim.models.TfidfModel(corpus)
# corpus_tfidf = tfidf[corpus]

# corpus_tfidf

# %%
# lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=4, id2word=diccionario, passes=10, workers=4)
# for idx, topic in lda_model_tfidf.print_topics(-1):
#     print('Topic: {} Word: {}'.format(idx, topic))

# %%
# Texto para probar - no atencion al ususario

# %%
data_prof['texto']= data_prof['Descripcion'].str.lower()
print('Elementos nulos', len(data_prof[data_prof['texto'].isna()]))

data_prof['texto'] = data_prof['texto'].fillna('')
print('Elementos nulos', len(data_prof[data_prof['texto'].isna()]))

txt_all = data_prof['texto'].values.tolist()

cleared_txt_all = remove_url(txt_all)
cleared_txt_all = remove_three_dots(cleared_txt_all)
cleared_txt_all = remove_breakline(cleared_txt_all)
cleared_txt_all = remove_single_quotes(cleared_txt_all)

data_palabras_all = list(texto_a_palabras2(cleared_txt_all))
# Out:
# C:\Users\johnk\AppData\Local\Temp/ipykernel_22036/2263175050.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_prof['texto']= data_prof['Descripcion'].str.lower()
# C:\Users\johnk\AppData\Local\Temp/ipykernel_22036/2263175050.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_prof['texto'] = data_prof['texto'].fillna('')
# Elementos nulos 11
# Elementos nulos 0

# %%
bigram_all = gensim.models.Phrases(data_palabras_all, min_count=5, threshold=100)
trigram_all = gensim.models.Phrases(bigram[data_palabras_all], threshold=100)

bigram_mod_all = gensim.models.phrases.Phraser(bigram_all)
trigram_mod_all = gensim.models.phrases.Phraser(trigram_all)

data_words_nostops_all = remove_stopwords(data_palabras_all)
data_words_bigrams_all = make_bigrams(data_words_nostops_all)

# %%
data_lemmatized_all = lemmatization(data_words_bigrams_all, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

diccionario_all = corpora.Dictionary(data_lemmatized_all)

# Corpus
texto_all = data_lemmatized_all
corpus_all = [diccionario.doc2bow(doc) for doc in texto_all]

# %%
# bow_vector = diccionario.doc2bow(data_palabras_all)

# %%
# corpus[0:10]

# %%
M1_list = []
for values, index, score in sorted(lda_model[corpus[0:1000]]):
    abc = [i[1] for i in values]
    M1_list.append(np.max(abc))
    
M2_list = []
for values, index, score in sorted(lda_model[corpus_all[0:1000]]):
    abc = [i[1] for i in values]
    M2_list.append(np.max(abc))
    
#
df_results = pd.DataFrame({
    'Ate. Usuario': M1_list,
    'Otros': M2_list,
})
ax = df_results.plot.kde()

# %%
[0.01907943, 0.07843247, 0.5459396, 0.3565485]
# Out:
# [0.01907943, 0.07843247, 0.5459396, 0.3565485]

# %%
M1_list = []
for values, index, score in sorted(lda_model[corpus[0:1000]]):
    abc = [i[1] for i in values]
    M1_list.append(np.max(abc))
    
M2_list = []
for values, index, score in sorted(lda_model[corpus_all[0:1000]]):
    abc = [i[1] for i in values]
    M2_list.append(np.min(abc))
    
#
df_results = pd.DataFrame({
    'Ate. Usuario': M1_list,
    'Otros': M2_list,
})
ax = df_results.plot.kde()

# %%
A B C D
 A .3 4 .5 .4
 O
# Out:
#   File "C:\Users\johnk\AppData\Local\Temp/ipykernel_22036/495897071.py", line 1
#     A B C D
#       ^
# SyntaxError: invalid syntax

# %%
### TOdos los valores

features = []
target = []
for values, index, score in sorted(lda_model[corpus[0:1000]]):
    abc = [i[1] for i in values]
    features.append(np.array(abc))
    target.append(1)
    
for values, index, score in sorted(lda_model[corpus_all[0:1000]]):
    abc = [i[1] for i in values]
    features.append(np.array(abc))
    target.append(0)
    
df_results = pd.DataFrame(features, columns = ['A', 'B', 'C', 'D'])
df_results['target']=target
df_results = df_results.fillna(0)
df_results.head()

# %%
features = np.array(features)
target = np.array(target)

features = df_results[['A', 'B', 'C', 'D']].values
target = df_results['target'].values

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, Y_train, Y_test = train_test_split(features, target, test_size=0.2,random_state=109)

# %%
X_test[0]

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
#clf = svm.SVC(kernel='linear', C=0.1) # Linear Kernel
clf = svm.SVC(kernel='poly',degree=3, coef0=1, C=0.1) # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, Y_train)

# #Predict the response for test dataset
Y_pred = clf.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(Y_test, Y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(Y_test, Y_pred))

# %% [markdown]
# # Procesos para nuevos Reclamos - Resultados

# %% [markdown]
# #### Leyendo fuentes

# %%
# Reclamos
file_name = 'data/data_merged.csv'
data_pending_process = pd.read_pickle(file_name)

# %% [markdown]
# #### Filtrando data

# %%
data_pending_process = data_pending_process[(data_pending_process['fecha fase 1'].dt.year>=2021) &
                                            (data_pending_process['fecha fase 1'].dt.month>=7) & 
                                            (data_pending_process['fecha fase 3'].isnull())
                                           ]

#data_pending_process.head()
print('Procesar',len(data_pending_process), 'datos')

# %%
# Filtramos solo nivel 1
data_pending_process = data_pending_process[data_pending_process['Nivel']=='1er'].reset_index(drop=True)

# Fitering to "Atencion al usuario"
data_pending_process = data_pending_process[(data_pending_process['Servicio SBS']=='96')]

#data_pending_process.head()
print('Procesar',len(data_pending_process), 'datos')

# %% [markdown]
# #### Preparacion del texto

# %%
data_pending_process['texto']= data_pending_process['Descripcion'].str.lower()
data_pending_process['texto'] = data_pending_process['texto'].fillna('')

txt_pending = data_pending_process['texto'].values.tolist()
cleared_txt_pending = remove_url(txt_pending)
cleared_txt_pending = remove_three_dots(cleared_txt_pending)
cleared_txt_pending = remove_breakline(cleared_txt_pending)
cleared_txt_pending = remove_single_quotes(cleared_txt_pending)

data_palabras_pending = list(texto_a_palabras2(cleared_txt_pending))

bigram_pending = gensim.models.Phrases(data_palabras_pending, min_count=5, threshold=100)
trigram_pending = gensim.models.Phrases(bigram[data_palabras_pending], threshold=100)

bigram_mod_pending = gensim.models.phrases.Phraser(bigram_pending)
trigram_mod_pending = gensim.models.phrases.Phraser(trigram_pending)

data_words_nostops_pending = remove_stopwords(data_palabras_pending)
data_words_bigrams_pending = make_bigrams(data_words_nostops_pending)

data_lemmatized_pending = lemmatization(data_words_bigrams_pending, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
corpus_pendig = [diccionario.doc2bow(doc) for doc in data_lemmatized_pending]

# %%
worlds_topic = []
umbral = []
for values, index, score in sorted(lda_model[corpus_pendig]):
    # print(values)
    abc = [i[1] for i in values]
    max_val = np.max(abc)
#     umbral.append(max_val)
#     worlds_topic.append(abc.index(max_val)+1)
    
    umbral.append(abc)
    worlds_topic.append(abc.index(max_val)+1)

data_pending_process['worlds_topic'] = worlds_topic
data_pending_process['umbral'] = umbral

# %%
data_pending_process[['Numero reclamo', 'Nombre', 'Numero documento',  'Descripcion', 'Departamento', 'Provincia', 'Distrito', 
       'fecha fase 1', 'Canal Incidencia SBS', 'Servicio SBS', 'Motivo SBS',
       'Canal Incidencia', 'Servicio', 'Motivo', 'Nivel', 'texto',
       'worlds_topic', 'umbral']]

# %%
# !pip list
